# %%
import requests
import pandas as pd

# %%
url = f'https://api.github.com/users'

# %%
headers = {"Authorization": 'token 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'}

# %%
response = requests.get(url , headers=headers)

# %%
data = response.json()

# %%
data
# Out:
# [{'login': 'mojombo',
#   'id': 1,
#   'node_id': 'MDQ6VXNlcjE=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mojombo',
#   'html_url': 'https://github.com/mojombo',
#   'followers_url': 'https://api.github.com/users/mojombo/followers',
#   'following_url': 'https://api.github.com/users/mojombo/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mojombo/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mojombo/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mojombo/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mojombo/orgs',
#   'repos_url': 'https://api.github.com/users/mojombo/repos',
#   'events_url': 'https://api.github.com/users/mojombo/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mojombo/received_events',
#   'type': 'User',
#   'site_admin': False},
# ...

# %%
user_urls = [each['url'] for each in data]

# %%
print((user_urls))
# Out:
# ['https://api.github.com/users/mojombo', 'https://api.github.com/users/defunkt', 'https://api.github.com/users/pjhyett', 'https://api.github.com/users/wycats', 'https://api.github.com/users/ezmobius', 'https://api.github.com/users/ivey', 'https://api.github.com/users/evanphx', 'https://api.github.com/users/vanpelt', 'https://api.github.com/users/wayneeseguin', 'https://api.github.com/users/brynary', 'https://api.github.com/users/kevinclark', 'https://api.github.com/users/technoweenie', 'https://api.github.com/users/macournoyer', 'https://api.github.com/users/takeo', 'https://api.github.com/users/caged', 'https://api.github.com/users/topfunky', 'https://api.github.com/users/anotherjesse', 'https://api.github.com/users/roland', 'https://api.github.com/users/lukas', 'https://api.github.com/users/fanvsfan', 'https://api.github.com/users/tomtt', 'https://api.github.com/users/railsjitsu', 'https://api.github.com/users/nitay', 'https://api.github.com/users/kevwil', 'https://api.github.com/u
# ...

# %%
user_data_list = []

# %%
import time
import requests
import pandas as pd

user_data_list = []
headers = {"Authorization": 'token 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'}
for i in range(0,20000,100):
    print(i)
    urls = f'https://api.github.com/users?since={i}&per_page=100'
    response = requests.get(urls , headers=headers)
    data = response.json()
    user_urls = [each['url'] for each in data]
    print(user_urls)
    
    for user_url in user_urls:
        time.sleep(3)
        user_data = requests.get(user_url, headers=headers).json()
        user_repos_url = user_data['repos_url']
        print(user_repos_url)
        time.sleep(3)
        user_repos = requests.get(user_repos_url, headers=headers).json()
        user_login = user_data['login']
        user_id = user_data['id']
        print(user_id)
        user_name = user_data['name']
        user_email = user_data['email']
        user_twitter = user_data['twitter_username']
        user_public_repos = user_data['public_repos']
        user_forks = [each['forks'] for each in user_repos]
        try:
            average_user_forks = sum(user_forks) / len(user_forks)
        except ZeroDivisionError: 
            average_user_forks = 0
        user_followers = user_data['followers']
        user_following = user_data['following']
        # print(f"Login: {user_login}")
        # print(f"User: {user_id}")
        # print(f"Name: {user_name}")
        # print(f"Email: {user_email}")
        # print(f"Twitter: {user_twitter}")
        # print(f"Fork_avg: {average_user_forks}")
        # print(f"Followers: {user_followers}")
        # print(f"Following: {user_following}")
        user_dict = {
            'Login': user_login,
            'ID': user_id,
            'Name': user_name,
            'Email': user_email,
            'Twitter': user_twitter,
            'Followers': user_followers,
            'Following': user_following,
            'No of Repos':int(user_public_repos),
            'Fork_avg': average_user_forks
        }
        
        user_data_list.append(user_dict)

df = pd.DataFrame(user_data_list)

print(df)
# Out:
# https://api.github.com/users/mojombo/repos
# 66
#           Login  ID                Name                     Email  Twitter  \
# 0       mojombo   1  Tom Preston-Werner                      None  mojombo
# 1       defunkt   2     Chris Wanstrath                      None     None
# 2       pjhyett   3            PJ Hyett                      None     None
# 3        wycats   4         Yehuda Katz                      None   wycats
# 4      ezmobius   5   Ezra Zygmuntowicz                      None     None
# ..          ...  ..                 ...                       ...      ...
# 83  jamesgolick  37        James Golick     jamesgolick@gmail.com     None
# 84        atmos  38       Corey Donohoe           atmos@atmos.org     None
# 85      errfree  44                None                      None     None
# 86      mojodna  45    Seth Fitzsimmons                      None  mojodna
# 87    bmizerany  46      Blake Mizerany  blake.mizerany@gmail.com     None
#
# ...

# %%
df.head()
# Out:
#       Login  ID                Name Email  Twitter   Fork_avg  Followers  \
# 0   mojombo   1  Tom Preston-Werner  None  mojombo  75.966667      23926
# 1   defunkt   2     Chris Wanstrath  None     None  51.400000      22311
# 2   pjhyett   3            PJ Hyett  None     None  18.125000       8290
# 3    wycats   4         Yehuda Katz  None   wycats   3.266667      10201
# 4  ezmobius   5   Ezra Zygmuntowicz  None     None   9.000000        554
#
#    Following  No of Repos
# 0         11          NaN
# 1        215          NaN
# 2         30          NaN
# 3         13          NaN
# 4         13          NaN

# %%
df.to_csv("github_profiles.csv",index=False)
